# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from scipy import stats

# %%
df = pd.read_csv('/Users/steveadjorlolo/desktop/Drilling Optimization.csv')

# %%
df.head(3)
# Out:
#    Torque Ft-lbs     MD Ft
# 0          96.15  12225.89
# 1         288.46  12225.89
# 2         480.77  12225.89

# %%
plt.scatter(x='MD Ft',y='Torque Ft-lbs',data=df)

# %%
m,c,r,p,se = stats.linregress(x=df['MD Ft'],y=df['Torque Ft-lbs'])
x= df['MD Ft']
y_modeled = pd.Series(map(lambda a : m*a + c,x ))
plt.scatter(x='MD Ft',y='Torque Ft-lbs',data=df)
plt.plot(x,y_modeled)
tork_predictor = lambda a : m*a + c

# %%
print(r)
# Out:
# -0.9908365297928181

# %%
tork_predictor(1000)
# Out:
# 24461.921445493645

# %%
tork_predictor(11000)
# Out:
# 3635.251572137113
